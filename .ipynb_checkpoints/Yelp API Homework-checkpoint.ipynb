# %%
# !pip install yelpapi
# Out:
# Requirement already satisfied: yelpapi in c:\users\cathe\anacoda3\envs\dojo-env\lib\site-packages (2.5.0)
# Requirement already satisfied: requests in c:\users\cathe\anacoda3\envs\dojo-env\lib\site-packages (from yelpapi) (2.28.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\cathe\anacoda3\envs\dojo-env\lib\site-packages (from requests->yelpapi) (1.26.13)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\cathe\anacoda3\envs\dojo-env\lib\site-packages (from requests->yelpapi) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\cathe\anacoda3\envs\dojo-env\lib\site-packages (from requests->yelpapi) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\cathe\anacoda3\envs\dojo-env\lib\site-packages (from requests->yelpapi) (2022.9.24)

# %%
# Standard Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Additional Imports
import os, json, math, time
from yelpapi import YelpAPI
from tqdm.notebook import tqdm_notebook

# %% [markdown]
# # Load Credentials and Create Yelp API Object

# %%
with open('C://Users//cathe//.secret//yelp_api.json', 'r') as f:
   login = json.load(f)

# %%
login.keys()
# Out:
# dict_keys(['client-id', 'api-key'])

# %%
#login['api-key']

# %%
yelp = YelpAPI(login['api-key'], timeout_s = 5.0)

# %% [markdown]
#   # Define Search Terms and File Paths

# %%
location = 'Colorado Springs, CO 80918'
term = 'burger'

# %%
location.split(',')[0]
# Out:
# 'Colorado Springs'

# %%
FOLDER = 'Data/'

os.makedirs(FOLDER, exist_ok = True)
JSON_FILE = FOLDER+f"{location.split(',')[0]}-{term}.json"

# %%
JSON_FILE
# Out:
# 'Data/Colorado Springs-burger.json'

# %% [markdown]
# # Checking if JSON files exists and Create if doesn't

# %%
os.path.isfile(JSON_FILE)
# Out:
# True

# %%
file_exists = os.path.isfile(JSON_FILE)
if file_exists ==False:
    folder = os.path.dirname(JSON_FILE)
    if len(folder)>0:
        os.makedirs(folder,exist_ok = True)
    print(f"[i] {JSON_FILE} not found. Saving empty list to file.")
    with open(JSON_FILE, 'w') as f:
          json.dump([], f)
else:
    print(f"[i] {JSON_FILE} already exists.")
# Out:
# [i] Data/Colorado Springs-burger.json already exists.

# %%
os.path.isfile(JSON_FILE)
# Out:
# True

# %% [markdown]
# # Loading JSON File and account

# %% [markdown]
# # Making the first API Cell to get the first set of data

# %%
results = yelp.search_query(term = term, location = location)

# %%
type(results)
# Out:
# dict

# %%
len(results)
# Out:
# 3

# %%
results.keys()
# Out:
# dict_keys(['businesses', 'total', 'region'])

# %%
results['total']
# Out:
# 336

# %%
results['region']
# Out:
# {'center': {'longitude': -104.78141784667969, 'latitude': 38.91293036496606}}

# %%
results['businesses']
# Out:
# [{'id': 'K11SCcDeCAU7rz8m5nl-cQ',
#   'alias': 'drifters-hamburgers-colorado-springs',
#   'name': "Drifter's Hamburgers",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/hII5Tb-6pHUwoTEJ37zkuQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/drifters-hamburgers-colorado-springs?adjust_creative=Wu4pMr0hMYFmu59r03exTA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Wu4pMr0hMYFmu59r03exTA',
#   'review_count': 345,
#   'categories': [{'alias': 'burgers', 'title': 'Burgers'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#    {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 38.89644174733928, 'longitude': -104.8249967},
#   'transactions': ['delivery'],
#   'price': '$',
#   'location': {'address1': '4455 Mark Dabling Blvd',
#    'address2': '',
#    'address3': '',
#    'city': 'Colorado Springs',
#    'zip_code': '80907',
#    'country': 'US',
#    'state': 'CO',
#    'display_address': ['4455 Mark Dabling Blvd',
#     'Colorado Springs, CO 80907']},
#   'phone': '+17195488163',
#   'display_phone': '(719) 548-8163',
#   'distance': 4193.011509128375},
#  {'id': '4cHxYgk5F-LqdvWKheu0Jw',
#   'alias': 'bad-daddys-burger-bar-colorado-springs-3',
#   'name': "Bad Daddy's Burger Bar",
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/uxeA2TUxjfIV5BS7Fam8yw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/bad-daddys-burger-bar-colorado-springs-3?adjust_creative=Wu4pMr0hMYFmu59r03exTA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Wu4pMr0hMYFmu59r03exTA',
#   'review_count': 507,
#   'categories': [{'alias': 'burgers', 'title': 'Burgers'},
#    {'alias': 'bars', 'title': 'Bars'},
#    {'alias': 'newamerican', 'title': 'American (New)'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 38.96406, 'longitude': -104.793896},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '1765 Briargate Pkwy',
#    'address2': 'Ste 803',
#    'address3': '',
#    'city': 'Colorado Springs',
#    'zip_code': '80920',
#    'country': 'US',
#    'state': 'CO',
#    'display_address': ['1765 Briargate Pkwy',
#     'Ste 803',
#     'Colorado Springs, CO 80920']},
#   'phone': '+17194186845',
#   'display_phone': '(719) 418-6845',
#   'distance': 5786.876634553892},
#  {'id': 'XqaE3xTsbEYwbAcZag0mUQ',
#   'alias': 'rock-city-cafe-colorado-springs-2',
#   'name': 'Rock City Cafe',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/foMnRVNEEfKvl6ZxJVKtKQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/rock-city-cafe-colorado-springs-2?adjust_creative=Wu4pMr0hMYFmu59r03exTA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Wu4pMr0hMYFmu59r03exTA',
#   'review_count': 246,
#   'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#    {'alias': 'bars', 'title': 'Bars'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 38.924650936223635,
#    'longitude': -104.79324067282266},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '1812 Dominion Way',
#    'address2': '',
#    'address3': '',
#    'city': 'Colorado Springs',
#    'zip_code': '80918',
#    'country': 'US',
#    'state': 'CO',
#    'display_address': ['1812 Dominion Way', 'Colorado Springs, CO 80918']},
#   'phone': '+17194247151',
#   'display_phone': '(719) 424-7151',
#   'distance': 1656.7130004369355},
#  {'id': 'za5cS-dX7V2mdLo4zuwVEA',
#   'alias': 'acme-bar-and-grill-colorado-springs-3',
#   'name': 'ACME Bar and Grill',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/jd5tcgbz8BE2uDh4T_pB0w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/acme-bar-and-grill-colorado-springs-3?adjust_creative=Wu4pMr0hMYFmu59r03exTA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Wu4pMr0hMYFmu59r03exTA',
#   'review_count': 7,
#   'categories': [{'alias': 'bars', 'title': 'Bars'},
#    {'alias': 'bbq', 'title': 'Barbeque'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 38.91585, 'longitude': -104.77862},
#   'transactions': ['delivery', 'pickup'],
#   'location': {'address1': '2660 Vickers Dr',
#    'address2': None,
#    'address3': '',
#    'city': 'Colorado Springs',
#    'zip_code': '80918',
#    'country': 'US',
#    'state': 'CO',
#    'display_address': ['2660 Vickers Dr', 'Colorado Springs, CO 80918']},
#   'phone': '+17192944102',
#   'display_phone': '(719) 294-4102',
#   'distance': 397.5326005143808},
#  {'id': 'HxVG2j1yweJYP9T9V42zUg',
#   'alias': 'lazy-dog-restaurant-and-bar-colorado-springs-2',
#   'name': 'Lazy Dog Restaurant & Bar',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/uYH6tDk7FdXJIH7GZtmMrg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/lazy-dog-restaurant-and-bar-colorado-springs-2?adjust_creative=Wu4pMr0hMYFmu59r03exTA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Wu4pMr0hMYFmu59r03exTA',
#   'review_count': 521,
#   'categories': [{'alias': 'comfortfood', 'title': 'Comfort Food'},
#    {'alias': 'burgers', 'title': 'Burgers'},
#    {'alias': 'newamerican', 'title': 'American (New)'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 38.9415839, 'longitude': -104.79889},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '7605 Academy Blvd N',
#    'address2': '',
#    'address3': None,
#    'city': 'Colorado Springs',
#    'zip_code': '80920',
#    'country': 'US',
#    'state': 'CO',
#    'display_address': ['7605 Academy Blvd N', 'Colorado Springs, CO 80920']},
#   'phone': '+17194455851',
#   'display_phone': '(719) 445-5851',
#   'distance': 3526.431254936833},
#  {'id': 'bFkbpRZlz9MoOsiSQhfx3Q',
#   'alias': 'skirted-heifer-colorado-springs',
#   'name': 'Skirted Heifer',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/iM8B1HiXjIlyssRxjqY4ew/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/skirted-heifer-colorado-springs?adjust_creative=Wu4pMr0hMYFmu59r03exTA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Wu4pMr0hMYFmu59r03exTA',
#   'review_count': 1169,
#   'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 38.8370285078266, 'longitude': -104.8236923282},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '204 N Tejon',
#    'address2': '',
#    'address3': '',
#    'city': 'Colorado Springs',
#    'zip_code': '80903',
#    'country': 'US',
#    'state': 'CO',
#    'display_address': ['204 N Tejon', 'Colorado Springs, CO 80903']},
#   'phone': '+17196353276',
#   'display_phone': '(719) 635-3276',
#   'distance': 9199.145932413965},
#  {'id': 'sgPr8gJzxW27iknQ7dFhXQ',
#   'alias': 'hops-n-drops-colorado-springs-colorado-springs',
#   'name': 'Hops n Drops - Colorado Springs',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/XH4Tu_SoXD9sRNOF9t0tgg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/hops-n-drops-colorado-springs-colorado-springs?adjust_creative=Wu4pMr0hMYFmu59r03exTA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Wu4pMr0hMYFmu59r03exTA',
#   'review_count': 208,
#   'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#    {'alias': 'burgers', 'title': 'Burgers'},
#    {'alias': 'bars', 'title': 'Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 38.91132, 'longitude': -104.71729},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '5820 Stetson Hills Blvd',
#    'address2': None,
#    'address3': '',
#    'city': 'Colorado Springs',
#    'zip_code': '80922',
#    'country': 'US',
#    'state': 'CO',
#    'display_address': ['5820 Stetson Hills Blvd',
#     'Colorado Springs, CO 80922']},
#   'phone': '+17195747219',
#   'display_phone': '(719) 574-7219',
#   'distance': 5516.797642576028},
#  {'id': 'ME6WqOKSAaI-MOK7Fg5ITw',
#   'alias': 'the-public-house-at-the-alexander-colorado-springs',
#   'name': 'The Public House at The Alexander',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/1EnfDFhBDvv_WKOWFlJKYw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/the-public-house-at-the-alexander-colorado-springs?adjust_creative=Wu4pMr0hMYFmu59r03exTA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Wu4pMr0hMYFmu59r03exTA',
#   'review_count': 71,
#   'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#    {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 38.877293448821256,
#    'longitude': -104.8201527612014},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '3104 N Nevada Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'Colorado Springs',
#    'zip_code': '80907',
#    'country': 'US',
#    'state': 'CO',
#    'display_address': ['3104 N Nevada Ave', 'Colorado Springs, CO 80907']},
#   'phone': '+17193758495',
#   'display_phone': '(719) 375-8495',
#   'distance': 5190.364257967584},
#  {'id': '4h42qiA4ar6L4E5esu9kjA',
#   'alias': 'grumpy-s-burgers-and-biscuits-colorado-springs',
#   'name': 'Grumpy’s Burgers And Biscuits',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/7QeUKRH6Xewg7Yov5YpcOw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/grumpy-s-burgers-and-biscuits-colorado-springs?adjust_creative=Wu4pMr0hMYFmu59r03exTA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Wu4pMr0hMYFmu59r03exTA',
#   'review_count': 1,
#   'categories': [{'alias': 'foodtrucks', 'title': 'Food Trucks'},
#    {'alias': 'burgers', 'title': 'Burgers'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 38.84627, 'longitude': -104.86175},
#   'transactions': [],
#   'location': {'address1': '2407 W Colorado Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'Colorado Springs',
#    'zip_code': '80904',
#    'country': 'US',
#    'state': 'CO',
#    'display_address': ['2407 W Colorado Ave', 'Colorado Springs, CO 80904']},
#   'phone': '+17193577907',
#   'display_phone': '(719) 357-7907',
#   'distance': 10161.651614801967},
#  {'id': 'hSP7TsNtaFl9FUPlAlxVWQ',
#   'alias': 'brakemans-burgers-colorado-springs',
#   'name': "Brakeman's Burgers",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/7SnsiQJmxxuTFzx4Skw3Fw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/brakemans-burgers-colorado-springs?adjust_creative=Wu4pMr0hMYFmu59r03exTA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Wu4pMr0hMYFmu59r03exTA',
#   'review_count': 100,
#   'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#    {'alias': 'salad', 'title': 'Salad'},
#    {'alias': 'burgers', 'title': 'Burgers'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 38.834068, 'longitude': -104.82897},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '10 S Sierra Madre St',
#    'address2': None,
#    'address3': '',
#    'city': 'Colorado Springs',
#    'zip_code': '80903',
#    'country': 'US',
#    'state': 'CO',
#    'display_address': ['10 S Sierra Madre St', 'Colorado Springs, CO 80903']},
#   'phone': '+17193758769',
#   'display_phone': '(719) 375-8769',
#   'distance': 9674.816150114339},
#  {'id': 'aHqnp1vl0pTPgYX269WSwA',
#   'alias': 'the-well-colorado-springs-2',
#   'name': 'The Well',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/7irky2_a-BQV75iUyCkGfg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/the-well-colorado-springs-2?adjust_creative=Wu4pMr0hMYFmu59r03exTA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Wu4pMr0hMYFmu59r03exTA',
#   'review_count': 38,
#   'categories': [{'alias': 'food_court', 'title': 'Food Court'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 38.833421345530624,
#    'longitude': -104.8193567549474},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '315 E Pikes Peak Ave',
#    'address2': None,
#    'address3': None,
#    'city': 'Colorado Springs',
#    'zip_code': '80903',
#    'country': 'US',
#    'state': 'CO',
#    'display_address': ['315 E Pikes Peak Ave', 'Colorado Springs, CO 80903']},
#   'phone': '+17194013726',
#   'display_phone': '(719) 401-3726',
#   'distance': 9431.331244797051},
#  {'id': 'Yi8ni7S9184dm9j-XxIjhQ',
#   'alias': 'bunzys-and-booze-colorado-springs',
#   'name': "Bunzy's & Booze",
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/agBToON1QMSx81lGsLL2QA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/bunzys-and-booze-colorado-springs?adjust_creative=Wu4pMr0hMYFmu59r03exTA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Wu4pMr0hMYFmu59r03exTA',
#   'review_count': 28,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'sandwiches', 'title': 'Sandwiches'},
#    {'alias': 'burgers', 'title': 'Burgers'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 38.83837, 'longitude': -104.7919},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '1919 E Boulder St',
#    'address2': '',
#    'address3': None,
#    'city': 'Colorado Springs',
#    'zip_code': '80909',
#    'country': 'US',
#    'state': 'CO',
#    'display_address': ['1919 E Boulder St', 'Colorado Springs, CO 80909']},
#   'phone': '+17192035522',
#   'display_phone': '(719) 203-5522',
#   'distance': 8343.698568426473},
#  {'id': 'GXOWObyBIpoGG4VgLa4s1g',
#   'alias': 'atmosphere-gastropub-colorado-springs',
#   'name': 'Atmosphere Gastropub',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/hbJfO4Ue__hfMIlxK54KLA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/atmosphere-gastropub-colorado-springs?adjust_creative=Wu4pMr0hMYFmu59r03exTA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Wu4pMr0hMYFmu59r03exTA',
#   'review_count': 337,
#   'categories': [{'alias': 'gastropubs', 'title': 'Gastropubs'},
#    {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 38.990489, 'longitude': -104.801201},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '1327 Interquest Pkwy',
#    'address2': None,
#    'address3': '',
#    'city': 'Colorado Springs',
#    'zip_code': '80921',
#    'country': 'US',
#    'state': 'CO',
#    'display_address': ['1327 Interquest Pkwy', 'Colorado Springs, CO 80921']},
#   'phone': '+17193544764',
#   'display_phone': '(719) 354-4764',
#   'distance': 8792.153099738955},
#  {'id': 'CTREXgZKaG1P8_kLP-EieA',
#   'alias': 'bjs-velvet-freez-colorado-springs',
#   'name': "BJ's Velvet Freez",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ULJUdll3ZzWIw7wE8C73Ew/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/bjs-velvet-freez-colorado-springs?adjust_creative=Wu4pMr0hMYFmu59r03exTA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Wu4pMr0hMYFmu59r03exTA',
#   'review_count': 206,
#   'categories': [{'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'},
#    {'alias': 'burgers', 'title': 'Burgers'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 38.8545917719603,
#    'longitude': -104.794198572636},
#   'transactions': ['delivery'],
#   'price': '$',
#   'location': {'address1': '1511 N Union Blvd',
#    'address2': '',
#    'address3': '',
#    'city': 'Colorado Springs',
#    'zip_code': '80909',
#    'country': 'US',
#    'state': 'CO',
#    'display_address': ['1511 N Union Blvd', 'Colorado Springs, CO 80909']},
#   'phone': '+17196336365',
#   'display_phone': '(719) 633-6365',
#   'distance': 6571.163605292538},
#  {'id': 'VwA-6xJTaoHML70chXxNuQ',
#   'alias': 'phantom-canyon-colorado-springs',
#   'name': 'Phantom Canyon',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/V9ogHVG9A_3xO3VzIIVA2w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/phantom-canyon-colorado-springs?adjust_creative=Wu4pMr0hMYFmu59r03exTA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Wu4pMr0hMYFmu59r03exTA',
#   'review_count': 1681,
#   'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#    {'alias': 'breweries', 'title': 'Breweries'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 38.834252, 'longitude': -104.824955},
#   'transactions': ['delivery', 'restaurant_reservation', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '2 E Pikes Peak Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Colorado Springs',
#    'zip_code': '80903',
#    'country': 'US',
#    'state': 'CO',
#    'display_address': ['2 E Pikes Peak Ave', 'Colorado Springs, CO 80903']},
#   'phone': '+17196352800',
#   'display_phone': '(719) 635-2800',
#   'distance': 9526.635941075128},
#  {'id': 'zycLBb33Yi84gmVOe0E6lg',
#   'alias': 'fat-shack-colorado-springs',
#   'name': 'Fat Shack',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/SATHcIWoWSrRMaPJg4YfVQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/fat-shack-colorado-springs?adjust_creative=Wu4pMr0hMYFmu59r03exTA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Wu4pMr0hMYFmu59r03exTA',
#   'review_count': 92,
#   'categories': [{'alias': 'burgers', 'title': 'Burgers'},
#    {'alias': 'chicken_wings', 'title': 'Chicken Wings'},
#    {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 38.9397904148333,
#    'longitude': -104.759375117719},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '3578 Hartsel Dr',
#    'address2': '',
#    'address3': None,
#    'city': 'Colorado Springs',
#    'zip_code': '80920',
#    'country': 'US',
#    'state': 'CO',
#    'display_address': ['3578 Hartsel Dr', 'Colorado Springs, CO 80920']},
#   'phone': '+17195989333',
#   'display_phone': '(719) 598-9333',
#   'distance': 3543.4769928863675},
#  {'id': 'UcsgZMhdKbZS-aHtt-OTHg',
#   'alias': 'crazy-heifer-colorado-springs',
#   'name': 'Crazy Heifer',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/p0mns5ySUeBmEPu0rQ8wWg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/crazy-heifer-colorado-springs?adjust_creative=Wu4pMr0hMYFmu59r03exTA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Wu4pMr0hMYFmu59r03exTA',
#   'review_count': 1,
#   'categories': [{'alias': 'burgers', 'title': 'Burgers'},
#    {'alias': 'foodtrucks', 'title': 'Food Trucks'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 38.8723362, 'longitude': -104.7073278},
#   'transactions': [],
#   'location': {'address1': '1175 Piros Dr',
#    'address2': '',
#    'address3': None,
#    'city': 'Colorado Springs',
#    'zip_code': '80903',
#    'country': 'US',
#    'state': 'CO',
#    'display_address': ['1175 Piros Dr', 'Colorado Springs, CO 80903']},
#   'phone': '+17197260361',
#   'display_phone': '(719) 726-0361',
#   'distance': 7841.606433162755},
#  {'id': 'Fs8MBqJ5w2XREdq7uWxZ4w',
#   'alias': 'red-leg-brewing-company-colorado-springs',
#   'name': 'Red Leg Brewing Company',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Y54OomTC-yN6eEc9KZWvPg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/red-leg-brewing-company-colorado-springs?adjust_creative=Wu4pMr0hMYFmu59r03exTA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Wu4pMr0hMYFmu59r03exTA',
#   'review_count': 192,
#   'categories': [{'alias': 'breweries', 'title': 'Breweries'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 38.896179, 'longitude': -104.870597},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '2323 Garden Of The Gods Rd',
#    'address2': None,
#    'address3': '',
#    'city': 'Colorado Springs',
#    'zip_code': '80907',
#    'country': 'US',
#    'state': 'CO',
#    'display_address': ['2323 Garden Of The Gods Rd',
#     'Colorado Springs, CO 80907']},
#   'phone': '+17195983776',
#   'display_phone': '(719) 598-3776',
#   'distance': 7933.41738384304},
#  {'id': 'DlWc8bYq0SG9J32zlgHJrg',
#   'alias': 'bubbas-33-colorado-springs',
#   'name': "Bubba's 33",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/RQ_NcD3ZIIsaEFyG6SmODA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/bubbas-33-colorado-springs?adjust_creative=Wu4pMr0hMYFmu59r03exTA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Wu4pMr0hMYFmu59r03exTA',
#   'review_count': 451,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'tradamerican', 'title': 'American (Traditional)'},
#    {'alias': 'burgers', 'title': 'Burgers'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 38.87102, 'longitude': -104.71891337913323},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '5807 Constitution Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Colorado Springs',
#    'zip_code': '80915',
#    'country': 'US',
#    'state': 'CO',
#    'display_address': ['5807 Constitution Ave', 'Colorado Springs, CO 80915']},
#   'phone': '+17195761223',
#   'display_phone': '(719) 576-1223',
#   'distance': 7140.0745983184415},
#  {'id': 'W6uchkbpeMecP7HpHv-s0g',
#   'alias': 'smashburger-colorado-springs-7',
#   'name': 'Smashburger',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/iHoNPD4pTkF8YmSn4IZwGw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/smashburger-colorado-springs-7?adjust_creative=Wu4pMr0hMYFmu59r03exTA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Wu4pMr0hMYFmu59r03exTA',
#   'review_count': 146,
#   'categories': [{'alias': 'burgers', 'title': 'Burgers'}],
#   'rating': 3.0,
#   'coordinates': {'latitude': 38.90699, 'longitude': -104.81803377272851},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$',
#   'location': {'address1': '5320 N Nevada Ave',
#    'address2': 'Ste 100',
#    'address3': '',
#    'city': 'Colorado Springs',
#    'zip_code': '80918',
#    'country': 'US',
#    'state': 'CO',
#    'display_address': ['5320 N Nevada Ave',
#     'Ste 100',
#     'Colorado Springs, CO 80918']},
#   'phone': '+17192190500',
#   'display_phone': '(719) 219-0500',
#   'distance': 3236.2988340792695}]

# %%
pd.DataFrame(results['businesses'])
# Out:
#                         id                                              alias  \
# 0   K11SCcDeCAU7rz8m5nl-cQ               drifters-hamburgers-colorado-springs
# 1   4cHxYgk5F-LqdvWKheu0Jw           bad-daddys-burger-bar-colorado-springs-3
# 2   XqaE3xTsbEYwbAcZag0mUQ                  rock-city-cafe-colorado-springs-2
# 3   za5cS-dX7V2mdLo4zuwVEA              acme-bar-and-grill-colorado-springs-3
# 4   HxVG2j1yweJYP9T9V42zUg     lazy-dog-restaurant-and-bar-colorado-springs-2
# 5   bFkbpRZlz9MoOsiSQhfx3Q                    skirted-heifer-colorado-springs
# 6   sgPr8gJzxW27iknQ7dFhXQ     hops-n-drops-colorado-springs-colorado-springs
# 7   ME6WqOKSAaI-MOK7Fg5ITw  the-public-house-at-the-alexander-colorado-spr...
# 8   4h42qiA4ar6L4E5esu9kjA     grumpy-s-burgers-and-biscuits-colorado-springs
# 9   hSP7TsNtaFl9FUPlAlxVWQ                 brakemans-burgers-colorado-springs
# 10  aHqnp1vl0pTPgYX269WSwA                        the-well-colorado-springs-2
# 11  Yi8ni7S9184dm9j-XxIjhQ                  bunzys-and-booze-colorado-springs
# 12  GXOWObyBIpoGG4VgLa4s1g              atmosphere-gastropub-colorado-springs
# 13  CTREXgZKaG1P8_kLP-EieA                  bjs-velvet-freez-colorado-springs
# 14  VwA-6xJTaoHML70chXxNuQ                    phantom-canyon-colorado-springs
# 15  zycLBb33Yi84gmVOe0E6lg                         fat-shack-colorado-springs
# 16  UcsgZMhdKbZS-aHtt-OTHg                      crazy-heifer-colorado-springs
# 17  Fs8MBqJ5w2XREdq7uWxZ4w           red-leg-brewing-company-colorado-springs
# 18  DlWc8bYq0SG9J32zlgHJrg                         bubbas-33-colorado-springs
# 19  W6uchkbpeMecP7HpHv-s0g                     smashburger-colorado-springs-7
#
#                                  name  \
# 0                Drifter's Hamburgers
# 1              Bad Daddy's Burger Bar
# 2                      Rock City Cafe
# 3                  ACME Bar and Grill
# 4           Lazy Dog Restaurant & Bar
# 5                      Skirted Heifer
# 6     Hops n Drops - Colorado Springs
# 7   The Public House at The Alexander
# 8       Grumpy’s Burgers And Biscuits
# 9                  Brakeman's Burgers
# 10                           The Well
# 11                    Bunzy's & Booze
# 12               Atmosphere Gastropub
# 13                  BJ's Velvet Freez
# 14                     Phantom Canyon
# 15                          Fat Shack
# 16                       Crazy Heifer
# 17            Red Leg Brewing Company
# 18                         Bubba's 33
# 19                        Smashburger
#
#                                             image_url  is_closed  \
# 0   https://s3-media3.fl.yelpcdn.com/bphoto/hII5Tb...      False
# 1   https://s3-media1.fl.yelpcdn.com/bphoto/uxeA2T...      False
# 2   https://s3-media4.fl.yelpcdn.com/bphoto/foMnRV...      False
# 3   https://s3-media4.fl.yelpcdn.com/bphoto/jd5tcg...      False
# 4   https://s3-media3.fl.yelpcdn.com/bphoto/uYH6tD...      False
# 5   https://s3-media1.fl.yelpcdn.com/bphoto/iM8B1H...      False
# 6   https://s3-media3.fl.yelpcdn.com/bphoto/XH4Tu_...      False
# 7   https://s3-media1.fl.yelpcdn.com/bphoto/1EnfDF...      False
# 8   https://s3-media3.fl.yelpcdn.com/bphoto/7QeUKR...      False
# 9   https://s3-media2.fl.yelpcdn.com/bphoto/7SnsiQ...      False
# 10  https://s3-media2.fl.yelpcdn.com/bphoto/7irky2...      False
# 11  https://s3-media1.fl.yelpcdn.com/bphoto/agBToO...      False
# 12  https://s3-media1.fl.yelpcdn.com/bphoto/hbJfO4...      False
# 13  https://s3-media3.fl.yelpcdn.com/bphoto/ULJUdl...      False
# 14  https://s3-media2.fl.yelpcdn.com/bphoto/V9ogHV...      False
# 15  https://s3-media1.fl.yelpcdn.com/bphoto/SATHcI...      False
# 16  https://s3-media4.fl.yelpcdn.com/bphoto/p0mns5...      False
# 17  https://s3-media4.fl.yelpcdn.com/bphoto/Y54Oom...      False
# 18  https://s3-media3.fl.yelpcdn.com/bphoto/RQ_NcD...      False
# 19  https://s3-media3.fl.yelpcdn.com/bphoto/iHoNPD...      False
#
#                                                   url  review_count  \
# 0   https://www.yelp.com/biz/drifters-hamburgers-c...           345
# 1   https://www.yelp.com/biz/bad-daddys-burger-bar...           507
# 2   https://www.yelp.com/biz/rock-city-cafe-colora...           246
# 3   https://www.yelp.com/biz/acme-bar-and-grill-co...             7
# 4   https://www.yelp.com/biz/lazy-dog-restaurant-a...           521
# 5   https://www.yelp.com/biz/skirted-heifer-colora...          1169
# 6   https://www.yelp.com/biz/hops-n-drops-colorado...           208
# 7   https://www.yelp.com/biz/the-public-house-at-t...            71
# 8   https://www.yelp.com/biz/grumpy-s-burgers-and-...             1
# 9   https://www.yelp.com/biz/brakemans-burgers-col...           100
# 10  https://www.yelp.com/biz/the-well-colorado-spr...            38
# 11  https://www.yelp.com/biz/bunzys-and-booze-colo...            28
# 12  https://www.yelp.com/biz/atmosphere-gastropub-...           337
# 13  https://www.yelp.com/biz/bjs-velvet-freez-colo...           206
# 14  https://www.yelp.com/biz/phantom-canyon-colora...          1681
# 15  https://www.yelp.com/biz/fat-shack-colorado-sp...            92
# 16  https://www.yelp.com/biz/crazy-heifer-colorado...             1
# 17  https://www.yelp.com/biz/red-leg-brewing-compa...           192
# 18  https://www.yelp.com/biz/bubbas-33-colorado-sp...           451
# 19  https://www.yelp.com/biz/smashburger-colorado-...           146
#
#                                            categories  rating  \
# 0   [{'alias': 'burgers', 'title': 'Burgers'}, {'a...     4.0
# 1   [{'alias': 'burgers', 'title': 'Burgers'}, {'a...     4.0
# 2   [{'alias': 'tradamerican', 'title': 'American ...     4.5
# 3   [{'alias': 'bars', 'title': 'Bars'}, {'alias':...     4.5
# 4   [{'alias': 'comfortfood', 'title': 'Comfort Fo...     4.0
# 5   [{'alias': 'tradamerican', 'title': 'American ...     4.0
# 6   [{'alias': 'newamerican', 'title': 'American (...     4.0
# 7   [{'alias': 'pubs', 'title': 'Pubs'}, {'alias':...     4.5
# 8   [{'alias': 'foodtrucks', 'title': 'Food Trucks...     5.0
# 9   [{'alias': 'tradamerican', 'title': 'American ...     3.5
# 10   [{'alias': 'food_court', 'title': 'Food Court'}]     4.5
# 11  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     5.0
# 12  [{'alias': 'gastropubs', 'title': 'Gastropubs'...     4.5
# 13  [{'alias': 'icecream', 'title': 'Ice Cream & F...     4.5
# 14  [{'alias': 'newamerican', 'title': 'American (...     4.0
# 15  [{'alias': 'burgers', 'title': 'Burgers'}, {'a...     3.5
# 16  [{'alias': 'burgers', 'title': 'Burgers'}, {'a...     5.0
# 17     [{'alias': 'breweries', 'title': 'Breweries'}]     4.5
# 18  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.0
# 19         [{'alias': 'burgers', 'title': 'Burgers'}]     3.0
#
#                                           coordinates  \
# 0   {'latitude': 38.89644174733928, 'longitude': -...
# 1    {'latitude': 38.96406, 'longitude': -104.793896}
# 2   {'latitude': 38.924650936223635, 'longitude': ...
# 3     {'latitude': 38.91585, 'longitude': -104.77862}
# 4   {'latitude': 38.9415839, 'longitude': -104.79889}
# 5   {'latitude': 38.8370285078266, 'longitude': -1...
# 6     {'latitude': 38.91132, 'longitude': -104.71729}
# 7   {'latitude': 38.877293448821256, 'longitude': ...
# 8     {'latitude': 38.84627, 'longitude': -104.86175}
# 9    {'latitude': 38.834068, 'longitude': -104.82897}
# 10  {'latitude': 38.833421345530624, 'longitude': ...
# 11     {'latitude': 38.83837, 'longitude': -104.7919}
# 12  {'latitude': 38.990489, 'longitude': -104.801201}
# 13  {'latitude': 38.8545917719603, 'longitude': -1...
# 14  {'latitude': 38.834252, 'longitude': -104.824955}
# 15  {'latitude': 38.9397904148333, 'longitude': -1...
# 16  {'latitude': 38.8723362, 'longitude': -104.707...
# 17  {'latitude': 38.896179, 'longitude': -104.870597}
# 18  {'latitude': 38.87102, 'longitude': -104.71891...
# 19  {'latitude': 38.90699, 'longitude': -104.81803...
#
#                                   transactions price  \
# 0                                   [delivery]     $
# 1                           [delivery, pickup]    $$
# 2                                   [delivery]    $$
# 3                           [delivery, pickup]   NaN
# 4                           [delivery, pickup]    $$
# 5                           [delivery, pickup]    $$
# 6                           [delivery, pickup]    $$
# 7                                           []    $$
# 8                                           []   NaN
# 9                                   [delivery]    $$
# 10                                          []    $$
# 11                                          []    $$
# 12                                  [delivery]    $$
# 13                                  [delivery]     $
# 14  [delivery, restaurant_reservation, pickup]    $$
# 15                          [delivery, pickup]    $$
# 16                                          []   NaN
# 17                                          []    $$
# 18                                  [delivery]    $$
# 19                          [delivery, pickup]     $
#
#                                              location         phone  \
# 0   {'address1': '4455 Mark Dabling Blvd', 'addres...  +17195488163
# 1   {'address1': '1765 Briargate Pkwy', 'address2'...  +17194186845
# 2   {'address1': '1812 Dominion Way', 'address2': ...  +17194247151
# 3   {'address1': '2660 Vickers Dr', 'address2': No...  +17192944102
# 4   {'address1': '7605 Academy Blvd N', 'address2'...  +17194455851
# 5   {'address1': '204 N Tejon', 'address2': '', 'a...  +17196353276
# 6   {'address1': '5820 Stetson Hills Blvd', 'addre...  +17195747219
# 7   {'address1': '3104 N Nevada Ave', 'address2': ...  +17193758495
# 8   {'address1': '2407 W Colorado Ave', 'address2'...  +17193577907
# 9   {'address1': '10 S Sierra Madre St', 'address2...  +17193758769
# 10  {'address1': '315 E Pikes Peak Ave', 'address2...  +17194013726
# 11  {'address1': '1919 E Boulder St', 'address2': ...  +17192035522
# 12  {'address1': '1327 Interquest Pkwy', 'address2...  +17193544764
# 13  {'address1': '1511 N Union Blvd', 'address2': ...  +17196336365
# 14  {'address1': '2 E Pikes Peak Ave', 'address2':...  +17196352800
# 15  {'address1': '3578 Hartsel Dr', 'address2': ''...  +17195989333
# 16  {'address1': '1175 Piros Dr', 'address2': '', ...  +17197260361
# 17  {'address1': '2323 Garden Of The Gods Rd', 'ad...  +17195983776
# 18  {'address1': '5807 Constitution Ave', 'address...  +17195761223
# 19  {'address1': '5320 N Nevada Ave', 'address2': ...  +17192190500
#
#      display_phone      distance
# 0   (719) 548-8163   4193.011509
# 1   (719) 418-6845   5786.876635
# 2   (719) 424-7151   1656.713000
# 3   (719) 294-4102    397.532601
# 4   (719) 445-5851   3526.431255
# 5   (719) 635-3276   9199.145932
# 6   (719) 574-7219   5516.797643
# 7   (719) 375-8495   5190.364258
# 8   (719) 357-7907  10161.651615
# 9   (719) 375-8769   9674.816150
# 10  (719) 401-3726   9431.331245
# 11  (719) 203-5522   8343.698568
# 12  (719) 354-4764   8792.153100
# 13  (719) 633-6365   6571.163605
# 14  (719) 635-2800   9526.635941
# 15  (719) 598-9333   3543.476993
# 16  (719) 726-0361   7841.606433
# 17  (719) 598-3776   7933.417384
# 18  (719) 576-1223   7140.074598
# 19  (719) 219-0500   3236.298834

# %%
results_per_page = len(results['businesses'])
results_per_page
# Out:
# 20

# %%
n_pages = math.ceil((results['total'])/results_per_page)
n_pages
# Out:
# 17

# %%
for i in tqdm_notebook( range(1,n_pages+1)):
    try:
        
        time.sleep(.2)
        
        with open(JSON_FILE, 'r') as f:
            previous_results = json.load(f)
        
        n_results = len(previous_results)
        
        previous_results.extend(results['businesses'])
        
        with open(JSON_FILE, 'w') as f:
            json.dump(previous_results,f)
            
    except Exception as e:
        print('(1)ERROR', e)
# Out:
#   0%|          | 0/17 [00:00<?, ?it/s]

# %% [markdown]
# # Open Final JSON File with pandas

# %%
df = pd.read_json(JSON_FILE)

# %%
df.head()
# Out:
#                        id                                           alias  \
# 0  K11SCcDeCAU7rz8m5nl-cQ            drifters-hamburgers-colorado-springs
# 1  4cHxYgk5F-LqdvWKheu0Jw        bad-daddys-burger-bar-colorado-springs-3
# 2  XqaE3xTsbEYwbAcZag0mUQ               rock-city-cafe-colorado-springs-2
# 3  za5cS-dX7V2mdLo4zuwVEA           acme-bar-and-grill-colorado-springs-3
# 4  HxVG2j1yweJYP9T9V42zUg  lazy-dog-restaurant-and-bar-colorado-springs-2
#
#                         name  \
# 0       Drifter's Hamburgers
# 1     Bad Daddy's Burger Bar
# 2             Rock City Cafe
# 3         ACME Bar and Grill
# 4  Lazy Dog Restaurant & Bar
#
#                                            image_url  is_closed  \
# 0  https://s3-media3.fl.yelpcdn.com/bphoto/hII5Tb...      False
# 1  https://s3-media1.fl.yelpcdn.com/bphoto/uxeA2T...      False
# 2  https://s3-media4.fl.yelpcdn.com/bphoto/foMnRV...      False
# 3  https://s3-media4.fl.yelpcdn.com/bphoto/jd5tcg...      False
# 4  https://s3-media3.fl.yelpcdn.com/bphoto/uYH6tD...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/drifters-hamburgers-c...           345
# 1  https://www.yelp.com/biz/bad-daddys-burger-bar...           507
# 2  https://www.yelp.com/biz/rock-city-cafe-colora...           246
# 3  https://www.yelp.com/biz/acme-bar-and-grill-co...             7
# 4  https://www.yelp.com/biz/lazy-dog-restaurant-a...           521
#
#                                           categories  rating  \
# 0  [{'alias': 'burgers', 'title': 'Burgers'}, {'a...     4.0
# 1  [{'alias': 'burgers', 'title': 'Burgers'}, {'a...     4.0
# 2  [{'alias': 'tradamerican', 'title': 'American ...     4.5
# 3  [{'alias': 'bars', 'title': 'Bars'}, {'alias':...     4.5
# 4  [{'alias': 'comfortfood', 'title': 'Comfort Fo...     4.0
#
#                                          coordinates        transactions  \
# 0  {'latitude': 38.89644174733928, 'longitude': -...          [delivery]
# 1   {'latitude': 38.96406, 'longitude': -104.793896}  [delivery, pickup]
# 2  {'latitude': 38.924650936223635, 'longitude': ...          [delivery]
# 3    {'latitude': 38.91585, 'longitude': -104.77862}  [delivery, pickup]
# 4  {'latitude': 38.9415839, 'longitude': -104.79889}  [delivery, pickup]
#
#   price                                           location        phone  \
# 0     $  {'address1': '4455 Mark Dabling Blvd', 'addres...  17195488163
# 1    $$  {'address1': '1765 Briargate Pkwy', 'address2'...  17194186845
# 2    $$  {'address1': '1812 Dominion Way', 'address2': ...  17194247151
# 3   NaN  {'address1': '2660 Vickers Dr', 'address2': No...  17192944102
# 4    $$  {'address1': '7605 Academy Blvd N', 'address2'...  17194455851
#
#     display_phone     distance
# 0  (719) 548-8163  4193.011509
# 1  (719) 418-6845  5786.876635
# 2  (719) 424-7151  1656.713000
# 3  (719) 294-4102   397.532601
# 4  (719) 445-5851  3526.431255

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 680 entries, 0 to 679
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             680 non-null    object
#  1   alias          680 non-null    object
#  2   name           680 non-null    object
#  3   image_url      680 non-null    object
#  4   is_closed      680 non-null    bool
#  5   url            680 non-null    object
#  6   review_count   680 non-null    int64
#  7   categories     680 non-null    object
#  8   rating         680 non-null    float64
#  9   coordinates    680 non-null    object
#  10  transactions   680 non-null    object
#  11  price          578 non-null    object
#  12  location       680 non-null    object
#  13  phone          680 non-null    int64
#  14  display_phone  680 non-null    object
#  15  distance       680 non-null    float64
# dtypes: bool(1), float64(2), int64(2), object(11)
# memory usage: 80.5+ KB

# %%
csv_file = JSON_FILE.replace('.json', '.csv.gz')
csv_file
# Out:
# 'Data/Colorado Springs-burger.csv.gz'

# %%
df.to_csv(csv_file,compression = 'gzip', index = False)

# %% [markdown]
# # Bonus

# %%
size_json = os.path.getsize(JSON_FILE)
size_csv_gz = os.path.getsize(JSON_FILE.replace('.json','.csv.gz'))

print(f'JSON_FILE: {size_json:,} Bytes')
print(f'CSV_GZ FILE: {size_csv_gz,} Bytes')
print(f'the csv.gz is {size_json/size_csv_gz} times smaller')
# Out:
# JSON_FILE: 701,862 Bytes
# CSV_GZ FILE: (8293,) Bytes
# the csv.gz is 84.63306402990474 times smaller
